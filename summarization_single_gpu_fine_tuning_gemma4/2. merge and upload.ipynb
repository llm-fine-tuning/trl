# %%
from peft import AutoPeftModelForCausalLM
from transformers import AutoTokenizer
from huggingface_hub import HfApi
import torch

peft_model_id = "gemma4-e4b-finance-new-summarizer/checkpoint-186"
base_model_id = "google/gemma-4-E4B-it"
merged_path = "merged"

# LoRA Adapter가 결합된 파인튜닝 모델 로드
fine_tuned_model = AutoPeftModelForCausalLM.from_pretrained(
    peft_model_id,
    device_map="auto",
    dtype=torch.bfloat16,
)

# LoRA Adapter를 base model에 병합
merged_model = fine_tuned_model.merge_and_unload()

# 병합 모델 저장
merged_model.save_pretrained(
    merged_path,
    safe_serialization=True,
)

# 토크나이저 로드 및 저장
tokenizer = AutoTokenizer.from_pretrained(base_model_id)
tokenizer.save_pretrained(merged_path)

processor = AutoProcessor.from_pretrained(base_model_id)
processor.save_pretrained(merged_path)

print(f"Merged model saved to: {merged_path}")
# Out:
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Merged model saved to: merged

# %%
api = HfApi()

username = "iamjoon"
MODEL_NAME = "gemma4-e4b-finance-new-summarizer-checkpoint-186"

api.create_repo(
    token="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",
    repo_id=f"{username}/{MODEL_NAME}",
    repo_type="model",
    exist_ok=True,
)

api.upload_folder(
    token="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",
    repo_id=f"{username}/{MODEL_NAME}",
    folder_path=merged_path,
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/iamjoon/gemma4-e4b-finance-new-summarizer-checkpoint-186/commit/9ccd122bdecaef52ba413734e6fb5d3a0dcdf5d2', commit_message='Upload folder using huggingface_hub', commit_description='', oid='9ccd122bdecaef52ba413734e6fb5d3a0dcdf5d2', pr_url=None, repo_url=RepoUrl('https://huggingface.co/iamjoon/gemma4-e4b-finance-new-summarizer-checkpoint-186', endpoint='https://huggingface.co', repo_type='model', repo_id='iamjoon/gemma4-e4b-finance-new-summarizer-checkpoint-186'), pr_revision=None, pr_num=None)
